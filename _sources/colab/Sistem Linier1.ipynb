# %% [markdown]
# - penyelesaian tunggal
# - sistem dengan tak terhingga penyelesaian
# - [penyelesaian sistem persamaan linier (Eliminasi Gauss)]
# - Mentransformasi sistem
# - Subtitusi

# %% [markdown]
# - [Menggambar persamaan bidang 3D]
# - Matplotib
